# %% [markdown]
# <a href="https://colab.research.google.com/github/stephintoto/ICT-ASSIGNMENTS/blob/main/case_stud_data_pre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
house= pd.read_csv('House_Pricing.csv')
house.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
df= df.drop(columns=['No of Times Visited'])

# %%
df.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
null_col=house[['Sale Price', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
          'Area of the House from Basement (in Sqft)','Zipcode','Latitude', 'Longitude','Living Area after Renovation (in Sqft)']]
null_col
# Out:
#        Sale Price  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0        221900.0             1.00               1180.0              5650.0
# 1        538000.0             2.25               2570.0              7242.0
# 2        180000.0             1.00                770.0             10000.0
# 3        604000.0             3.00               1960.0              5000.0
# 4        510000.0             2.00               1680.0              8080.0
# ...           ...              ...                  ...                 ...
# 21608    360000.0             2.50               1530.0              1131.0
# 21609    400000.0             2.50               2310.0              5813.0
# 21610    402101.0             0.75               1020.0              1350.0
# 21611    400000.0             2.50               1600.0              2388.0
# 21612    325000.0             0.75               1020.0              1076.0
#
# ...

# %% [markdown]
# Filling NULL values using simple imputer

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imputer=imputer.fit(null_col)
null_col=imputer.transform(null_col)

# %%
null_col=pd.DataFrame(null_col,columns=['Sale Price', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
          'Area of the House from Basement (in Sqft)','Zipcode','Latitude', 'Longitude','Living Area after Renovation (in Sqft)'])
null_col.isna().sum()
# Out:
# Sale Price                                   0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# Area of the House from Basement (in Sqft)    0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
house = pd.read_csv('House_Pricing.csv')
num_columns = len(house.columns)
rows = (num_columns // 2) + (num_columns % 2)
fig, axes = plt.subplots(rows, 2, figsize=(20, 4 * rows))

for i, column in enumerate(house.columns):
    sns.boxplot(x=house[column], ax=axes[i // 2, i % 2])
    axes[i // 2, i % 2].set_title(f'Boxplot of {column}')

if num_columns % 2 != 0:
    fig.delaxes(axes[-1, -1])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=house['Sale Price'])
plt.title('Boxplot of Sale Price')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(house['Sale Price'], kde=True)
plt.title('Distribution of Sale Price')
plt.show()

# %%
Q1 = house['Sale Price'].quantile(0.25)
Q3 = house['Sale Price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)

house = house[(house['Sale Price'] >= lower_bound) & (house['Sale Price'] <= upper_bound)]
# Out:
# -112500.0
# 1027500.0

# %%
house=house.drop(columns=['No of Times Visited'])

# %%
house['Log Sale Price'] = np.log1p(house['Sale Price'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Sale Price'])
plt.title('Boxplot of Sale Price')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(df['Sale Price'], kde=True)
plt.title('Distribution of Sale Price')
plt.show()

# %%
import pandas as pd
house = pd.read_csv('House_Pricing.csv')
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

exclude_columns = ['ID']

for column in house.select_dtypes(include=['float64', 'int64']).columns:
    if column not in exclude_columns:
        house = remove_outliers(house, column)

print(house.describe())
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  1.484100e+04  1.484100e+04    14841.000000     14841.000000
# mean   4.707073e+09  4.394246e+05        3.234957         1.951974
# std    2.854539e+09  1.813834e+05        0.766626         0.647224
# min    2.800031e+06  8.200000e+04        2.000000         0.500000
# 25%    2.310000e+09  3.000000e+05        3.000000         1.500000
# 50%    4.031700e+09  4.050000e+05        3.000000         2.000000
# 75%    7.379700e+09  5.500000e+05        4.000000         2.500000
# max    9.900000e+09  1.120000e+06        5.000000         4.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         14841.000000        14841.000000  14841.000000   14841.000000
# mean           1773.739371         6845.096085      1.450711       7.352739
# std             567.528261         3196.698386      0.548503       0.784383
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

num_columns = len(house.columns)
rows = (num_columns // 2) + (num_columns % 2)
fig, axes = plt.subplots(rows, 2, figsize=(20, 4 * rows))

for i, column in enumerate(house.columns):
    sns.boxplot(x=house[column], ax=axes[i // 2, i % 2])
    axes[i // 2, i % 2].set_title(f'Boxplot of {column}')

if num_columns % 2 != 0:
    fig.delaxes(axes[-1, -1])

# %%
house=house.drop(columns=['No of Times Visited'])

# %%
house= house.drop(columns=['Date House was Sold'])

# %%
house.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
data1=pd.get_dummies(house,columns=['Condition of the House'])
data1.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
# 6  1321400060    257500.0               3             2.25
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
# 6               1715.0              6819.0           2.0              No
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Zipcode  \
# 0              7                                     1180.0  ...  98178.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Condition of the House']= le.fit_transform(df['Condition of the House'])

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numerical_columns = house.select_dtypes(include=['float64', 'int64']).columns
numerical_columns = numerical_columns.drop(['ID'])  # Exclude the ID column


house[numerical_columns] = scaler.fit_transform(house[numerical_columns])


print(house.head())
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    0.134778        0.333333         0.142857
# 2  5631500400    0.094412        0.000000         0.142857
# 3  2487200875    0.502890        0.666667         0.714286
# 4  1954400510    0.412331        0.333333         0.428571
# 6  1321400060    0.169075        0.333333         0.500000
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0             0.183976            0.295865           0.0              No
# 2             0.062315            0.546744           0.0              No
# 3             0.415430            0.258377           0.0              No
# 4             0.332344            0.436011           0.0              No
# 6             0.342730            0.363285           0.4              No
#
#   Condition of the House  Overall Grade  \
# 0                   Fair       0.333333
# 2                   Fair       0.000000
# 3              Excellent       0.333333
# ...
